# %% [markdown]
# <a href="https://colab.research.google.com/github/Inishpy/DeepLearningWork/blob/main/TinyLLama_1_1B_model_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install huggingface_hub

# %%
from huggingface_hub import snapshot_download
model_id="TinyLlama/TinyLlama-1.1B-Chat-v1.0"
snapshot_download(repo_id=model_id, local_dir="tinyLLamadir",
                  local_dir_use_symlinks=False, revision="main")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 10 files:   0%|          | 0/10 [00:00<?, ?it/s]
# special_tokens_map.json:   0%|          | 0.00/551 [00:00<?, ?B/s]
# eval_results.json:   0%|          | 0.00/566 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.14k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/608 [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# ...

# %%
# !git clone https://github.com/ggerganov/llama.cpp.git
# Out:
# Cloning into 'llama.cpp'...
# remote: Enumerating objects: 17285, done.
# remote: Counting objects: 100% (132/132), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 17285 (delta 67), reused 99 (delta 46), pack-reused 17153
# Receiving objects: 100% (17285/17285), 20.79 MiB | 18.45 MiB/s, done.
# Resolving deltas: 100% (11962/11962), done.

# %%
pip install -r llama.cpp/requirements.txt

# %%
# !python llama.cpp/convert.py -h
# Out:
# usage: convert.py [-h] [--awq-path AWQ_PATH] [--dump] [--dump-single] [--vocab-only]
#                   [--outtype {f32,f16,q8_0}] [--vocab-dir VOCAB_DIR] [--vocab-type {spm,bpe,hfft}]
#                   [--outfile OUTFILE] [--ctx CTX] [--concurrency CONCURRENCY] [--big-endian]
#                   [--pad-vocab]
#                   model
#
# Convert a LLaMa model to a GGML compatible file
#
# positional arguments:
#   model                 directory containing model file, or model file itself (*.pth, *.pt, *.bin)
#
# options:
#   -h, --help            show this help message and exit
#   --awq-path AWQ_PATH   Path to scale awq cache file
#   --dump                don't convert, just show what's in the model
#   --dump-single         don't convert, just show what's in a single model file
#   --vocab-only          extract only the vocab
#   --outtype {f32,f16,q8_0}
#                         output format - note: q8_0 may be very slow (default: f16 or f32 based on
# ...

# %%
# !python llama.cpp/convert.py tinyLLamadir \
  --outfile TinyLlama-1.1B-Chat-v1.0.gguf \
  --outtype q8_0
# Out:
# Loading model file tinyLLamadir/model.safetensors
# params = Params(n_vocab=32000, n_embd=2048, n_layer=22, n_ctx=2048, n_ff=5632, n_head=32, n_head_kv=4, n_experts=None, n_experts_used=None, f_norm_eps=1e-05, rope_scaling_type=None, f_rope_freq_base=10000.0, f_rope_scale=None, n_orig_ctx=None, rope_finetuned=None, ftype=<GGMLFileType.MostlyQ8_0: 7>, path_model=PosixPath('tinyLLamadir'))
# Found vocab files: {'tokenizer.model': PosixPath('tinyLLamadir/tokenizer.model'), 'vocab.json': None, 'tokenizer.json': PosixPath('tinyLLamadir/tokenizer.json')}
# Loading vocab file 'tinyLLamadir/tokenizer.model', type 'spm'
# Vocab info: <SentencePieceVocab with 32000 base tokens and 0 added tokens>
# Special vocab info: <SpecialVocab with 0 merges, special tokens {'bos': 1, 'eos': 2, 'unk': 0, 'pad': 2}, add special tokens unset>
# Permuting layer 0
# Permuting layer 1
# Permuting layer 2
# Permuting layer 3
# Permuting layer 4
# Permuting layer 5
# Permuting layer 6
# Permuting layer 7
# ...

# %%
# !set HUGGING_FACE_HUB_TOKEN="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"

# %%
from huggingface_hub import HfApi
api = HfApi()

model_id = "Inishds/TinyLlama-1.1B-Chat-v1.0"
api.create_repo(model_id, exist_ok=True, repo_type="model", token="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")
api.upload_file(
    path_or_fileobj="TinyLlama-1.1B-Chat-v1.0.gguf",
    path_in_repo="TinyLlama-1.1B-Chat-v1.0.gguf",
    repo_id=model_id,
)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     285     try:
# --> 286         response.raise_for_status()
#     287     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/api/models/Inishds/TinyLlama-1.1B-Chat-v1.0/preupload/main
#
# The above exception was the direct cause of the following exception:
#
# RepositoryNotFoundError                   Traceback (most recent call last)
# <ipython-input-12-cc2a3f173201> in <cell line: 6>()
#       4 model_id = "Inishds/TinyLlama-1.1B-Chat-v1.0"
# ...

# %%
api.upload_file(
    path_or_fileobj="TinyLlama-1.1B-Chat-v1.0.gguf",
    path_in_repo="TinyLlama-1.1B-Chat-v1.0.gguf",
    repo_id=model_id,
)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     285     try:
# --> 286         response.raise_for_status()
#     287     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/api/models/Inishds/TinyLlama-1.1B-Chat-v1.0/preupload/main
#
# The above exception was the direct cause of the following exception:
#
# RepositoryNotFoundError                   Traceback (most recent call last)
# <ipython-input-13-6674fad84153> in <cell line: 1>()
# ----> 1 api.upload_file(
# ...
